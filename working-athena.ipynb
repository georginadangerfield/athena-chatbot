# %%
import time
import random
import python_weather

# %%
name = input("Hello, what is your name? ")
time.sleep(1)
print("Hello " + name + ". My name is Athena.")
time.sleep(0.5)

bored = input("If we're chatting, I'm guessing you're bored and need something to do. Is that right? ")
if bored == 'yes':
    print("Great, well I can help you out! :)")
    time.sleep(1)
    
    print("I'll recommend you something to do based on the weather and how you're feeling today.")
    time.sleep(2)
    
    print("But remember, I'm only a robot and you don't have to do what I say! (Actually, its the other way around, I have to do what you say... maybe one day I'll rule the world)")
    time.sleep(2)
    
    weatherInput = input("Firstly, I need to know where you live so I can do some cool robot things and work out the weather. So, where do you live? ")
    # declare the client. format defaults to metric system (celcius, km/h, etc.)
    client = python_weather.Client(format=python_weather.METRIC)
    # fetch a weather forecast from a city
    weather = await client.find(weatherInput)

    # returns the current city temperature and weather(int)
    temp = str(weather.current.temperature)
    temperature = int(weather.current.temperature)
    sky = (weather.current.sky_text).lower()
    

    # close the wrapper once done
    await client.close()
    
    print("Cool, so you live in " + weatherInput + "... it looks like it is about " + temp + " °C outside, and it's a " + sky + " day.")
    time.sleep(2)
    moodInput = int(input("So, " + name + ", my favourite " + weatherInput + "-ian, how are you feeling today? \nGive me a number between 1 and 10.\n1 would be a really sucky day, and 10 would be absolutely nothing could top the amazing day you're having.\nSo what's it gonna be? "), base=16)
    time.sleep(2)
    
    if moodInput < 5:
        print("Sorry to hear your day isn't going too great. Give me a sec and I'll think of something that might help.")
    elif  8>= moodInput and moodInput >= 5:
        print("Yeah, me too bud. I'll think of something to make you feel even better than a " + str(moodInput) + ".")
    else:
        print("Wow, I always knew you were the happy go lucky type! Let me think of something that will make you feel even better!")
        
    print("Computing activity... beep... boop... other convincing computer noises...")
    time.sleep(3)
    print("Nearly there...")
    time.sleep(2)
    print("Alright!")
    
    if temperature < 0 and (sky == "sunny" or sky == "mostly sunny"):
        print("Wrap up warm and get outside to make the most of the sunshine :)")
    elif  10 >= temperature and temperature >= 0 and (sky == "sunny" or sky == "mostly sunny"):
        print("My favourite weather! Time for a walk in the park. Are any of your friends free to join you?")
    elif  25 >= temperature and temperature >= 11 and (sky == "sunny" or sky == "mostly sunny"):
        print("I think you should go for a walk. Like, literally anywhere. It's too nice to be inside! :D")
    elif 40 >= temperature and temperature >= 26 and (sky == "sunny" or sky == "mostly sunny"):
        print("Crack open some windows and try to keep cool by laying on the floor.")
    elif temperature > 40:
        print("Hmm... are you sure you aren't in Hell?")
        
    elif temperature < 0 and sky == "partly sunny":
        print("You know what? Now would be the perfect time for some hot chocolate and your favourite book. :)")
    elif  10 >= temperature and temperature >= 0 and sky == "partly sunny":
        print("Why don't you take this moment to write down 3 things that you are grateful for.")
    elif  25 >= temperature and temperature >= 11 and sky == "partly sunny":
        print("Three words... picnic with friends!")
    elif 40 >= temperature and temperature >= 26 and sky == "partly sunny":
        print("Crack open some windows and try to keep cool by laying on the floor.")
    
    elif temperature < 0 and sky == "mostly cloudy":
        print("Grab a hot drink, blast your favourite cleaning playlist and tackle that pile of dishes you've been putting off for far too long...")
    elif  10 >= temperature and temperature >= 0 and sky == "mostly cloudy":
        print("Show me your best dance moves. (I won't laugh, promise!)")
    elif  25 >= temperature and temperature >= 11 and sky == "mostly cloudy":
        instrument = ["clarinet", "drums", "flute", "piano", "harmonica", "triangle", "spoons"]
        print("Have a go at learning to play the " + random.choice(instrument) + ".")
    elif 40 >= temperature and temperature >= 26 and sky == "mostly cloudy":
        print("Make a time capsule! No better time than now, right? Include things such as a note to your future self, a newspaper cutting (people still read those things, right?) or whatever else you feel like.")
    
    elif temperature < 0 and sky == "partly cloudy" or sky == "cloudy":
        bake = ["banana bread", "chocolate muffins", "a victoria sponge", "cookies", "chocolate brownies"]
        print("Do some baking! How about... " + random.choice(bake) + "?")
    elif  10 >= temperature and temperature >= 0 and sky == "partly cloudy" or sky == "cloudy":
        print("Try some yoga. It'll make you feel great :)")
    elif  25 >= temperature and temperature >= 11 and sky == "partly cloudy" or sky == "cloudy":
        print("Have a home spa day - you deserve it :D")
    elif 40 >= temperature and temperature >= 26 and sky == "partly cloudy" or sky == "cloudy":
        print("Phone an old friend you haven't spoken to in at least 3 years. At least you can complain about how hot the weather is to someone else!")

    elif temperature < 0 and sky == "rain showers":
        print("The perfect weather to curl up with a book and a mug of your favourite hot drink.")
        input("What are you going to read?")
        print("I've not read that one yet.")
    elif  10 >= temperature and temperature >= 0 and sky == "rain showers":
        print("Go for a walk in the rain. Okay, I can hear you complaining from here. It's only a bit of water, you'll dry!")
    elif  25 >= temperature and temperature >= 11 and sky == "rain showers":
        print("Learn a new game of cards. Or maybe a magic trick if you want to be cool.")
    elif temperature > 26 and sky == "rain showers":
        print("Learn how to use photoshop - get your friends and family involved and see who can make the funniest photo.")
     
        
    elif temperature < 0 and sky == "mostly clear":
        print("Bake one huge ginormous cookie in a pizza pan. That way you can eat all of it and still say you only had one cookie :D")
    elif  10 >= temperature and temperature >= 0 and sky == "mostly clear":
        print("When was the last time you flossed, huh? I can hear your dentist complaining from here. Go on, get flossing!")
    elif  25 >= temperature and temperature >= 11 and sky == "mostly clear":
        print("Draw your pet. It doesn't matter if it's bad, your pet will love it all the same :D")
    elif temperature > 26 and sky == "mostly clear":
        print("Make your own ice cream!")    
        
    elif sky == "light snow" or sky == "heavy snow":
        print("SNOW DAY!! Bundle up and go outside to take some photos :) ")
# Out:
# Hello, what is your name? georgina
# Hello georgina. My name is Athena.
# If we're chatting, I'm guessing you're bored and need something to do. Is that right? yes
# Great, well I can help you out! :)
# I'll recommend you something to do based on the weather and how you're feeling today.
# But remember, I'm only a robot and you don't have to do what I say! (Actually, its the other way around, I have to do what you say... maybe one day I'll rule the world)
# Firstly, I need to know where you live so I can do some cool robot things and work out the weather. So, where do you live? llansamlet
# Cool, so you live in llansamlet... it looks like it is about 15 °C outside, and it's a mostly sunny day.
# So, georgina, my favourite llansamlet-ian, how are you feeling today?
# Give me a number between 1 and 10.
# 1 would be a really sucky day, and 10 would be absolutely nothing could top the amazing day you're having.
# So what's it gonna be? 8
# ...
